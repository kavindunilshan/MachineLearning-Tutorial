# %%
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split

digits = load_digits()

X_train, X_test, y_train, y_test = train_test_split(digits.data, digits.target, test_size=0.25)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(max_iter=10000)

model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=10000)

# %%
model.predict(X_test)
# Out:
# array([5, 8, 2, 3, 4, 2, 4, 1, 7, 8, 5, 1, 4, 3, 7, 2, 9, 3, 9, 2, 5, 8,
#        8, 7, 4, 4, 6, 0, 9, 9, 1, 7, 3, 7, 9, 4, 2, 1, 5, 3, 5, 7, 4, 8,
#        2, 3, 8, 2, 1, 1, 6, 1, 0, 1, 7, 2, 4, 5, 8, 7, 3, 1, 2, 4, 7, 3,
#        1, 0, 9, 1, 4, 6, 2, 1, 0, 2, 4, 3, 8, 2, 0, 7, 1, 7, 1, 3, 8, 4,
#        6, 4, 7, 2, 2, 4, 2, 7, 9, 5, 1, 3, 0, 6, 9, 0, 2, 7, 7, 9, 3, 1,
#        4, 1, 1, 9, 4, 0, 6, 8, 6, 5, 2, 9, 6, 9, 5, 3, 6, 3, 1, 5, 4, 2,
#        3, 6, 5, 5, 3, 6, 0, 9, 8, 9, 4, 0, 6, 0, 9, 4, 0, 4, 4, 5, 3, 6,
#        3, 7, 1, 6, 3, 2, 6, 3, 6, 3, 6, 5, 9, 9, 8, 8, 3, 6, 2, 9, 9, 6,
#        0, 4, 5, 3, 5, 5, 0, 3, 3, 7, 1, 8, 6, 4, 6, 5, 1, 3, 6, 8, 7, 4,
#        0, 2, 8, 6, 4, 0, 9, 9, 9, 3, 9, 3, 2, 1, 2, 0, 3, 8, 8, 0, 8, 4,
#        5, 9, 1, 7, 6, 3, 8, 2, 1, 3, 1, 2, 7, 9, 7, 9, 0, 7, 9, 3, 6, 6,
#        7, 9, 2, 8, 8, 5, 1, 7, 9, 2, 4, 6, 2, 2, 0, 5, 6, 1, 0, 3, 1, 5,
#        6, 9, 2, 7, 7, 3, 8, 5, 4, 5, 2, 5, 6, 6, 7, 6, 6, 5, 7, 7, 5, 8,
#        6, 5, 8, 0, 5, 7, 5, 0, 2, 6, 9, 2, 5, 8, 9, 9, 4, 7, 9, 8, 5, 0,
#        2, 1, 5, 4, 7, 6, 0, 4, 2, 4, 1, 8, 2, 9, 7, 8, 7, 7, 3, 7, 7, 1,
#        0, 8, 0, 4, 7, 2, 0, 0, 2, 6, 7, 2, 7, 9, 3, 3, 4, 5, 4, 2, 1, 5,
#        9, 8, 3, 1, 8, 1, 5, 7, 0, 2, 0, 4, 9, 9, 4, 1, 0, 6, 3, 9, 5, 6,
#        7, 3, 9, 8, 4, 9, 3, 3, 1, 0, 8, 2, 3, 7, 5, 3, 8, 4, 1, 6, 6, 3,
#        1, 4, 5, 2, 7, 9, 8, 6, 0, 6, 6, 1, 3, 0, 7, 1, 7, 2, 7, 2, 5, 9,
#        9, 0, 1, 0, 9, 7, 3, 5, 3, 2, 2, 3, 2, 3, 3, 8, 4, 8, 3, 2, 0, 3,
#        3, 3, 5, 0, 4, 7, 2, 9, 9, 1])

# %%
model.score(X_test, y_test)
# Out:
# 0.9577777777777777

# %%
y_pred = model.predict(X_test)
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,7))
sns.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')
